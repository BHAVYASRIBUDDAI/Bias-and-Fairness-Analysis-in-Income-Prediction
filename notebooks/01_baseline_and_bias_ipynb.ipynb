# %%
import sys
sys.path.append('/content/fairness-folktables')

# %%
# !pip install folktables
# Out:
# Collecting folktables
#   Downloading folktables-0.0.12-py3-none-any.whl.metadata (533 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from folktables) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from folktables) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folktables) (2.32.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from folktables) (1.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->folktables) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->folktables) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->folktables) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folktables) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folktables) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folktables) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->folktables) (2026.1.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->folktables) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->folktables) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->folktables) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->folktables) (1.17.0)
# Downloading folktables-0.0.12-py3-none-any.whl (17 kB)
# Installing collected packages: folktables
# Successfully installed folktables-0.0.12

# %%
from src.data import load_data
from src.fairness_utils import evaluate_model

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
# Load California data
X, y, sex = load_data("CA")

X_train, X_test, y_train, y_test, s_train, s_test = train_test_split(
    X, y, sex, test_size=0.3, random_state=42, stratify=y
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# Downloading data for 2018 1-Year person survey for CA...

# %%
model = LogisticRegression(max_iter=2000)
model.fit(X_train_scaled, y_train)

baseline_results = evaluate_model(
    model, X_test_scaled, y_test, s_test
)

baseline_results
# Out:
# {'accuracy': 0.785434412265758,
#  'eo': {1: np.float64(0.7644404332129964), 2: np.float64(0.6447354852016087)},
#  'eo_gap': np.float64(0.11970494801138765),
#  'dp': {1: np.float64(0.4675857170530122), 2: np.float64(0.30790593666594535)},
#  'dp_gap': np.float64(0.15967978038706687)}
